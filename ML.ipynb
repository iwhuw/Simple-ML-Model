# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cyber_threats.csv")

# %%
print(df.head())
# Out:
#    Country  Year        Attack Type     Target Industry  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                    773169  Hacker Group
# 1                          62.19                    295961  Hacker Group
# 2                          38.65                    605895  Hacker Group
# 3                          41.44                    659320  Nation-state
# 4                          74.41                    810682       Insider
#
#   Security Vulnerability Type Defense Mechanism Used  \
# 0          Unpatched Software                    VPN
# 1          Unpatched Software               Firewall
# ...

# %%
print(df.tail())
# Out:
#       Country  Year    Attack Type     Target Industry  \
# 2995       UK  2021     Ransomware          Government
# 2996   Brazil  2023  SQL Injection  Telecommunications
# 2997   Brazil  2017  SQL Injection                  IT
# 2998       UK  2022  SQL Injection                  IT
# 2999  Germany  2021  SQL Injection              Retail
#
#       Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 2995                          51.42                    190694       Unknown
# 2996                          30.28                    892843  Hacker Group
# 2997                          32.97                    734737  Nation-state
# 2998                          32.17                    379954       Insider
# 2999                          48.20                    480984       Unknown
#
#      Security Vulnerability Type Defense Mechanism Used  \
# 2995          Social Engineering               Firewall
# 2996                    Zero-day                    VPN
# ...

# %%
print(df.shape)
# Out:
# (3000, 10)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              3000 non-null   object
#  1   Year                                 3000 non-null   int64
#  2   Attack Type                          3000 non-null   object
#  3   Target Industry                      3000 non-null   object
#  4   Financial Loss (in Million $)        3000 non-null   float64
#  5   Number of Affected Users             3000 non-null   int64
#  6   Attack Source                        3000 non-null   object
#  7   Security Vulnerability Type          3000 non-null   object
#  8   Defense Mechanism Used               3000 non-null   object
#  9   Incident Resolution Time (in Hours)  3000 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 234.5+ KB
# None

# %%
print(df.describe())
# Out:
#               Year  Financial Loss (in Million $)  Number of Affected Users  \
# count  3000.000000                    3000.000000               3000.000000
# mean   2019.570333                      50.492970             504684.136333
# std       2.857932                      28.791415             289944.084972
# min    2015.000000                       0.500000                424.000000
# 25%    2017.000000                      25.757500             255805.250000
# 50%    2020.000000                      50.795000             504513.000000
# 75%    2022.000000                      75.630000             758088.500000
# max    2024.000000                      99.990000             999635.000000
#
#        Incident Resolution Time (in Hours)
# count                          3000.000000
# mean                             36.476000
# std                              20.570768
# min                               1.000000
# 25%                              19.000000
# ...

# %%
print(df.columns)
# Out:
# Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)'],
#       dtype='object')

# %%
print(df["Attack Type"])
# Out:
# 0                Phishing
# 1              Ransomware
# 2       Man-in-the-Middle
# 3              Ransomware
# 4       Man-in-the-Middle
#               ...
# 2995           Ransomware
# 2996        SQL Injection
# 2997        SQL Injection
# 2998        SQL Injection
# 2999        SQL Injection
# Name: Attack Type, Length: 3000, dtype: object

# %%
print(df[["Attack Type","Year"]])
# Out:
#             Attack Type  Year
# 0              Phishing  2019
# 1            Ransomware  2019
# 2     Man-in-the-Middle  2017
# 3            Ransomware  2024
# 4     Man-in-the-Middle  2018
# ...                 ...   ...
# 2995         Ransomware  2021
# 2996      SQL Injection  2023
# 2997      SQL Injection  2017
# 2998      SQL Injection  2022
# 2999      SQL Injection  2021
#
# [3000 rows x 2 columns]

# %%
print(df.iloc[0])
# Out:
# Country                                             China
# Year                                                 2019
# Attack Type                                      Phishing
# Target Industry                                 Education
# Financial Loss (in Million $)                       80.53
# Number of Affected Users                           773169
# Attack Source                                Hacker Group
# Security Vulnerability Type            Unpatched Software
# Defense Mechanism Used                                VPN
# Incident Resolution Time (in Hours)                    63
# Name: 0, dtype: object

# %%
print(df[df["Year"] == 2021])
# Out:
#         Country  Year    Attack Type Target Industry  \
# 25        China  2021       Phishing          Retail
# 37        Japan  2021  SQL Injection          Retail
# 41        India  2021  SQL Injection              IT
# 56           UK  2021        Malware      Healthcare
# 69        China  2021       Phishing      Healthcare
# ...         ...   ...            ...             ...
# 2987  Australia  2021     Ransomware      Healthcare
# 2989     Brazil  2021     Ransomware       Education
# 2992         UK  2021        Malware         Banking
# 2995         UK  2021     Ransomware      Government
# 2999    Germany  2021  SQL Injection          Retail
#
#       Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 25                            51.06                    628562       Insider
# 37                            82.52                    214372       Insider
# 41                            98.09                    826976  Nation-state
# ...

# %%
print(df)
# Out:
#       Country  Year        Attack Type     Target Industry  \
# 0       China  2019           Phishing           Education
# 1       China  2019         Ransomware              Retail
# 2       India  2017  Man-in-the-Middle                  IT
# 3          UK  2024         Ransomware  Telecommunications
# 4     Germany  2018  Man-in-the-Middle                  IT
# ...       ...   ...                ...                 ...
# 2995       UK  2021         Ransomware          Government
# 2996   Brazil  2023      SQL Injection  Telecommunications
# 2997   Brazil  2017      SQL Injection                  IT
# 2998       UK  2022      SQL Injection                  IT
# 2999  Germany  2021      SQL Injection              Retail
#
#       Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                             80.53                    773169  Hacker Group
# 1                             62.19                    295961  Hacker Group
# ...

# %% [markdown]
# Data preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
print(df.isnull().sum())
# Out:
# Country                                0
# Year                                   0
# Attack Type                            0
# Target Industry                        0
# Financial Loss (in Million $)          0
# Number of Affected Users               0
# Attack Source                          0
# Security Vulnerability Type            0
# Defense Mechanism Used                 0
# Incident Resolution Time (in Hours)    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df["Year"].value_counts()
# Out:
# Year
# 2017    319
# 2022    318
# 2020    315
# 2023    315
# 2018    310
# 2021    299
# 2024    299
# 2016    285
# 2015    277
# 2019    263
# Name: count, dtype: int64

# %%
df.groupby("Year").mean(numeric_only = True)# numeric_only added as in this dataset with mixed data types, it was throwing error, so it need to be set to an appear as a int so it does not take it as a string.
# Out:
#       Financial Loss (in Million $)  Number of Affected Users  \
# Year
# 2015                      52.383430             510083.646209
# 2016                      48.937754             505384.505263
# 2017                      50.977053             507234.733542
# 2018                      47.485419             489596.625806
# 2019                      49.941787             495106.190114
# 2020                      50.056984             504878.606349
# 2021                      53.088328             519204.010033
# 2022                      49.908365             513406.163522
# 2023                      50.660571             489859.225397
# 2024                      51.619699             511977.648829
#
#       Incident Resolution Time (in Hours)
# Year
# 2015                            38.429603
# 2016                            35.922807
# 2017                            35.388715
# 2018                            36.980645
# 2019                            35.307985
# ...

# %% [markdown]
# Model Training

# %%
X = pd.get_dummies(df.drop(columns=["Financial Loss (in Million $)"]), drop_first=True)

# %%
print(X)
# Out:
#       Year  Number of Affected Users  Incident Resolution Time (in Hours)  \
# 0     2019                    773169                                   63
# 1     2019                    295961                                   71
# 2     2017                    605895                                   20
# 3     2024                    659320                                    7
# 4     2018                    810682                                   68
# ...    ...                       ...                                  ...
# 2995  2021                    190694                                   52
# 2996  2023                    892843                                   26
# 2997  2017                    734737                                   30
# 2998  2022                    379954                                    9
# 2999  2021                    480984                                   64
#
#       Country_Brazil  Country_China  Country_France  Country_Germany  \
# ...

# %%
Y = df["Year"]

# %%
print(Y)
# Out:
# 0       2019
# 1       2019
# 2       2017
# 3       2024
# 4       2018
#         ...
# 2995    2021
# 2996    2023
# 2997    2017
# 2998    2022
# 2999    2021
# Name: Year, Length: 3000, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["Financial Loss (in Million $)"] = le.fit_transform(df["Financial Loss (in Million $)"])

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
s_d = StandardScaler()  # Define the scaler
s_d.fit(X) 
X = s_d.transform(X)

# %%
print(s_d)
# Out:
# StandardScaler()

# %%
y = df["Year"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,stratify = y, random_state = 1)

# %%
from sklearn import svm

# %%
classifier = svm.SVC(kernel = 'linear')

# %%
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print("Accuracy Score of the training data : " ,training_data_accuracy," ", y_train)
# Out:
# Accuracy Score of the training data :  1.0   113     2016
# 2702    2017
# 2810    2024
# 1723    2021
# 976     2016
#         ...
# 507     2016
# 1909    2023
# 2446    2015
# 1173    2016
# 163     2024
# Name: Year, Length: 2400, dtype: int64
